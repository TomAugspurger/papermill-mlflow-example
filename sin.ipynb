# %% [markdown]
# # This notebook demonstrates papermill

# %%
a = 1
b = 1
c = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = a * np.sin(b * x) + c
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlim=(-10, 10));
